# %% [markdown]
# <a href="https://colab.research.google.com/github/inoueshinji8/PythonStudy/blob/main/NAIST_XRD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd NAIST_XRD/
# Out:
# /content/NAIST_XRD

# %%
# !ls
# Out:
# code_NAIST_XRD.zip

# %%
# !unzip code_NAIST_XRD.zip
# Out:
# Archive:  code_NAIST_XRD.zip
#    creating: code_NAIST_XRD/
#    creating: code_NAIST_XRD/data/
#   inflating: code_NAIST_XRD/data/BB_powder.ras
#   inflating: code_NAIST_XRD/data/Ge220_114longPSA.ras
#   inflating: code_NAIST_XRD/data/GI-XRD_Omega03deg.ras
#   inflating: code_NAIST_XRD/data/Inplane.ras
#   inflating: code_NAIST_XRD/data/RockingCurve.ras
#   inflating: code_NAIST_XRD/data/VT_powder.ras
#   inflating: code_NAIST_XRD/data/XRR.ras
#   inflating: code_NAIST_XRD/keypara.csv
#   inflating: code_NAIST_XRD/metadata_schema.xml
#    creating: code_NAIST_XRD/output/
#   inflating: code_NAIST_XRD/XRD_Rigaku_Smartlab_NAIST.py
#   inflating: code_NAIST_XRD/XRD_Rigaku_Smartlab_NAIST_xml.py

# %%
# %cd code_NAIST_XRD/
# Out:
# /content/NAIST_XRD/code_NAIST_XRD

# %%
# !ls
# Out:
# data	     metadata_schema.xml  XRD_Rigaku_Smartlab_NAIST.py
# keypara.csv  output		  XRD_Rigaku_Smartlab_NAIST_xml.py

# %%
# !python XRD_Rigaku_Smartlab_NAIST_xml.py
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# *MEAS_COND_AXIS_STATE-74 Fixed
# *MEAS_COND_AXIS_STATE-75 Fixed
# *MEAS_COND_AXIS_STATE-76 Fixed
# *MEAS_COND_AXIS_STATE-77 Fixed
# *MEAS_COND_AXIS_STATE-78 Fixed
# *MEAS_COND_AXIS_STATE-79 Fixed
# *MEAS_COND_AXIS_STATE-8 Fixed
# *MEAS_COND_AXIS_STATE-80 Fixed
# *MEAS_COND_AXIS_STATE-81 Fixed
# *MEAS_COND_AXIS_STATE-82 Fixed
# *MEAS_COND_AXIS_STATE-83 Fixed
# *MEAS_COND_AXIS_STATE-84 Fixed
# *MEAS_COND_AXIS_STATE-85 Fixed
# *MEAS_COND_AXIS_STATE-86 Fixed
# *MEAS_COND_AXIS_STATE-87 Fixed
# *MEAS_COND_AXIS_STATE-88 Fixed
# *MEAS_COND_AXIS_STATE-89 Fixed
# *MEAS_COND_AXIS_STATE-9 Fixed
# *MEAS_COND_AXIS_STATE-90 Fixed
# *MEAS_COND_AXIS_STATE-91 Fixed
# *MEAS_COND_AXIS_STATE-92 Fixed
# *MEAS_COND_AXIS_STATE-93 Fixed
# *MEAS_COND_AXIS_STATE-94 Fixed
# *MEAS_COND_AXIS_STATE-95 Fixed
# *MEAS_COND_AXIS_STATE-96 Fixed
# *MEAS_COND_AXIS_STATE-97 Fixed
# *MEAS_COND_AXIS_STATE-98 Fixed
# *MEAS_COND_AXIS_STATE-99 Fixed
# *MEAS_COND_AXIS_UNIT-0 deg
# ...

# %%
# !python XRD_Rigaku_Smartlab_NAIST.py
# Out:
# SHIFT_JIS
#       2theta  intensity
# 0      0.200   610.0710
# 1      0.202   577.3057
# 2      0.204   513.0860
# 3      0.206   530.3647
# 4      0.208   526.5818
# ...      ...        ...
# 4896   9.992     1.0031
# 4897   9.994     1.0282
# 4898   9.996     2.0201
# 4899   9.998     1.0588
# 4900  10.000     0.0000
#
# [4901 rows x 2 columns]
# Making plot in progress
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# <Figure size 1600x900 with 1 Axes>
# SHIFT_JIS
#      2theta  intensity
# 0     2.000   722.1842
# 1     2.064   659.3361
# 2     2.128   613.8596
# 3     2.192   628.4778
# 4     2.256   624.4767
# ..      ...        ...
# 433  29.712    42.0568
# 434  29.776    40.9373
# 435  29.840    43.9001
# 436  29.904    29.8897
# 437  29.968    35.0605
#
# [438 rows x 2 columns]
# Making plot in progress
# <Figure size 1600x900 with 1 Axes>
# SHIFT_JIS
# ...

# %%
# %cd ../
# Out:
# /content

# %%
# !ls
# Out:
# NAIST_NMR_JEOL	NAIST_XPS  NAIST_XRD  sample_data

# %%
# %cd NAIST_XPS/
# Out:
# /content/NAIST_XPS

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
#    creating: data/
#    creating: data/log/
#   inflating: data/log/20220215-1436-00.log
#    creating: data/meta/
#   inflating: data/meta/Si.103.1.json
#   inflating: data/meta/Si.107.1.json
#   inflating: data/meta/Si.108.1.json
#   inflating: data/meta/Si.109.1.json
#    creating: data/raw/
#   inflating: data/raw/Si.103.1.spe
#   inflating: data/raw/Si.107.1.spe
#   inflating: data/raw/Si.108.1.spe
#   inflating: data/raw/Si.109.1.spe
#    creating: data/structured/
#    creating: data/structured/csv/
#   inflating: data/structured/csv/Si.103.1_Survey.csv
#   inflating: data/structured/csv/Si.107.1_C1s.csv
#   inflating: data/structured/csv/Si.107.1_O1s.csv
#   inflating: data/structured/csv/Si.107.1_Si2p.csv
#   inflating: data/structured/csv/Si.108.1_Survey.csv
#   inflating: data/structured/csv/Si.109.1_C1s.csv
#   inflating: data/structured/csv/Si.109.1_O1s.csv
#   inflating: data/structured/csv/Si.109.1_Si2p.csv
# ...

# %%
# !unzip data_org.zip
# Out:
# Archive:  data_org.zip
#    creating: data_org/
#    creating: data_org/inputdata/
#   inflating: data_org/inputdata/Si.103.1.spe
#   inflating: data_org/inputdata/Si.107.1.spe
#   inflating: data_org/inputdata/Si.108.1.spe
#   inflating: data_org/inputdata/Si.109.1.spe

# %%
# !unzip output.zip
# Out:
# Archive:  output.zip
#    creating: output/
#   inflating: output/Si.103.1_Survey.png
#   inflating: output/Si.107.1_C1s.png
#   inflating: output/Si.107.1_O1s.png
#   inflating: output/Si.107.1_Si2p.png
#   inflating: output/Si.108.1_Survey.png
#   inflating: output/Si.109.1_C1s.png
#   inflating: output/Si.109.1_O1s.png
#   inflating: output/Si.109.1_Si2p.png

# %%
# !unzip scr.zip
# Out:
# Archive:  scr.zip
#    creating: scr/
#   inflating: scr/csv2img.py
#    creating: scr/data/
#    creating: scr/data/log/
#   inflating: scr/data/log/20220213-1436-20.log
#   inflating: scr/data/log/20220213-1506-15.log
#    creating: scr/data/meta/
#  extracting: scr/data/meta/metadata.json
#    creating: scr/data/raw/
#   inflating: scr/data/raw/XPS_PHI_QUANTERA_narrow.spe
#   inflating: scr/data/raw/XPS_PHI_QUANTERA_survey.spe
#    creating: scr/data/structured/
#    creating: scr/data/structured/csv/
#   inflating: scr/data/structured/csv/XPS_PHI_QUANTERA_narrow_C1s.csv
#   inflating: scr/data/structured/csv/XPS_PHI_QUANTERA_narrow_Cu2p.csv
#   inflating: scr/data/structured/csv/XPS_PHI_QUANTERA_narrow_Cu_LMM.csv
#   inflating: scr/data/structured/csv/XPS_PHI_QUANTERA_narrow_O1s.csv
#   inflating: scr/data/structured/csv/XPS_PHI_QUANTERA_survey_Survey.csv
#   inflating: scr/data/structured/XPS_PHI_QUANTERA_narrow.txt
#   inflating: scr/data/structured/XPS_PHI_QUANTERA_survey.txt
# ...

# %%
from scr import spe2txt,txt2csv,csv2img,txt2metajson

def main ():
    spe2txt.main()  #バイナリのテキスト変換
    txt2csv.main()  #上記テキストファイルから数値ファイル出力
    csv2img.main()  #数値ファイルから可視化図作成
    txt2metajson.main()  #選定メタデータを抽出
    
if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-30-2bef8a8796ae> in <module>()
# ----> 1 from scr import spe2txt,txt2csv,csv2img,txt2metajson
#       2
#       3 def main ():
#       4     spe2txt.main()  #バイナリのテキスト変換
#       5     txt2csv.main()  #上記テキストファイルから数値ファイル出力
#
# ImportError: cannot import name 'spe2txt' from 'scr' (/content/NAIST_NMR_JEOL/scr/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !python xps_ulvac_spectrum.py
# Out:
# /bin/sh: 1: wine: not found
#
# /bin/sh: 1: wine: not found
#
# /bin/sh: 1: wine: not found
#
# /bin/sh: 1: wine: not found
#
# In progress : data/structured/Si.103.1.txt
# data/structured/csv/Si.103.1_Survey.csv 53 1406
# In progress : data/structured/Si.107.1.txt
# data/structured/csv/Si.107.1_C1s.csv 57 101
# data/structured/csv/Si.107.1_O1s.csv 167 101
# data/structured/csv/Si.107.1_Si2p.csv 277 101
# In progress : data/structured/Si.108.1.txt
# data/structured/csv/Si.108.1_Survey.csv 53 1406
# In progress : data/structured/Si.109.1.txt
# data/structured/csv/Si.109.1_C1s.csv 57 101
# data/structured/csv/Si.109.1_O1s.csv 167 101
# data/structured/csv/Si.109.1_Si2p.csv 277 101
# Making plot in progress: output/Si.103.1_Survey.png
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# Making plot in progress: output/Si.107.1_C1s.png
# Making plot in progress: output/Si.107.1_O1s.png
# ...
